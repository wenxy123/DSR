# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Square results

# %% [markdown]
# ## Gaussian error

# %%
square_results1 = np.load('~/simresults1_DSR_square1.npz', allow_pickle=True)

square_results1_L2 = np.load('~/simresults1_regression_square1.npz', allow_pickle=True)

# %%
results1 = square_results1['results_square1'].item()  
results1_L2 = square_results1_L2['results_square1'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)


predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 13})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend(frameon=False)
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/square_gaussian_est_beta.svg',format='svg')
plt.show()

# %% [markdown]
# ## Uniform error

# %%
square_results2 = np.load('~/simresults1_DSR_square2.npz', allow_pickle=True)

square_results2_L2 = np.load('~/simresults1_regression_square2.npz', allow_pickle=True)

# %%
results1 = square_results2['results_square2'].item()  
results1_L2 = square_results2_L2['results_square2'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)


predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 15})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend()
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/square_uniform_est_beta.svg',format='svg')
plt.show()

# %% [markdown]
# # Log results

# %% [markdown]
# ## Gaussian error

# %%
log_results1 = np.load('~/simresults1_DSR_log1.npz', allow_pickle=True)

log_results1_L2 = np.load('~/simresults1_regression_log1.npz', allow_pickle=True)

# %%
results1 = log_results1['results_log1'].item()  
results1_L2 = log_results1_L2['results_log1'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)

predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 15})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend()
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/log_gaussian_est_beta.svg',format='svg')
plt.show()

# %% [markdown]
# ## Uniform error

# %%
log_results2 = np.load('~/simresults1_DSR_log2.npz', allow_pickle=True)

log_results2_L2 = np.load('~/simresults1_regression_log2.npz', allow_pickle=True)

# %%
results1 = log_results2['results_log2'].item()  
results1_L2 = log_results2_L2['results_log2'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)


predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 15})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend()
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/log_uniform_est_beta.svg',format='svg')
plt.show()

# %% [markdown]
# # Softplus function

# %% [markdown]
# ## Gaussian error

# %%
softplus_results1 = np.load('~/simresults1_engression_softplus1.npz', allow_pickle=True)

softplus_results1_L2 = np.load('~/simresults1_regression_softplus1.npz', allow_pickle=True)

# %%
results1 = softplus_results1['results_softplus1'].item()  
results1_L2 = softplus_results1_L2['results_softplus1'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)



predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 15})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend()
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/softplus_gaussian_est_beta.svg',format='svg')
plt.show()

# %% [markdown]
# ## Uniform error

# %%
softplus_results2 = np.load('~/simresults1_DSR_softplus2.npz', allow_pickle=True)

softplus_results2_L2 = np.load('~/simresults1_regression_softplus2.npz', allow_pickle=True)

# %%
results1 = softplus_results2['results_softplus2'].item()  
results1_L2 = softplus_results2_L2['results_softplus2'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)


predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 15})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend()
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/softplus_unifrom_est_beta.svg',format='svg')
plt.show()

# %% [markdown]
# # Cubic function

# %% [markdown]
# ## Gaussian error

# %%
cubic_results1 = np.load('~/simresults1_engression_cubic1.npz', allow_pickle=True)

cubic_results1_L2 = np.load('~/simresults1_regression_cubic1.npz', allow_pickle=True)

# %%
results1 = cubic_results1['results_cubic1'].item()  
results1_L2 = cubic_results1_L2['results_cubic1'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)


predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 15})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend()
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/cubic_gaussian_est_beta.svg',format='svg')
plt.show()

# %% [markdown]
# ## Uniform error

# %%
cubic_results2 = np.load('~/simresults1_engression_cubic2.npz', allow_pickle=True)

cubic_results2_L2 = np.load('~/simresults1_regression_cubic2.npz', allow_pickle=True)

# %%
results1 = cubic_results2['results_cubic2'].item()  
results1_L2 = cubic_results2_L2['results_cubic2'].item()

# %% [markdown]
# ### Estimate of function $g(\cdot)$, with $\hat{\beta}$

# %%
# Access the results
predicted_means = results1['predicted_means']                            
x_train = results1['x_train']
y_train = results1['y_train']
x_test = results1['x_test']   
y_true_mean = results1['y_true_mean']                       

y_mean = predicted_means.mean(axis=0)  
y_mean_lower = np.quantile(predicted_means, 0.10, axis=0)  
y_mean_upper = np.quantile(predicted_means, 0.90, axis=0)  

x_test = np.squeeze(x_test)  

y_mean = np.squeeze(y_mean)
y_mean_lower = np.squeeze(y_mean_lower)
y_mean_upper = np.squeeze(y_mean_upper)


predicted_means_L2 = results1_L2['predicted_means']                        
x_train_L2 = results1_L2['x_train']
y_train_L2 = results1_L2['y_train']
x_test_L2 = results1_L2['x_test']   
y_true_mean_L2 = results1_L2['y_true_mean']                        

y_mean_L2 = predicted_means_L2.mean(axis=0)  
y_lower_L2 = np.quantile(predicted_means_L2, 0.10, axis=0)  
y_upper_L2 = np.quantile(predicted_means_L2, 0.90, axis=0)  

x_test_L2 = np.squeeze(x_test_L2)  

y_mean_L2 = np.squeeze(y_mean_L2)
y_lower_L2 = np.squeeze(y_lower_L2)
y_upper_L2 = np.squeeze(y_upper_L2)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

plt.rcParams.update({'font.size': 15,'axes.labelsize':20,'xtick.labelsize':20,'ytick.labelsize':20,'legend.fontsize': 15})

# First subplot
ax1 = axes[0]
#ax1.spines[['right', 'top']].set_visible(False)
ax1.plot(x_test, y_mean, label='Mean of Predicted Means', color='blue')
ax1.plot(x_test, y_true_mean, label='Truth', color='C3')
ax1.fill_between(x_test, y_mean_lower, y_mean_upper, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax1.scatter(x_train, y_train, label="Training Data", s=1, color="silver")
ax1.set_xlabel('X')
ax1.set_ylabel('Predicted Mean of Y')
ax1.set_title('DSR')
#ax1.legend()
ax1.grid(False)

# Second subplot
ax2 = axes[1]
#ax2.spines[['right', 'top']].set_visible(False)
ax2.plot(x_test_L2, y_mean_L2, label='Mean of Predicted Means', color='blue')
ax2.plot(x_test_L2, y_true_mean_L2, label='Truth', color='C3')
ax2.fill_between(x_test_L2, y_lower_L2, y_upper_L2, color='skyblue', alpha=0.5, label='10% - 90% Quantile Interval')
ax2.scatter(x_train_L2, y_train_L2, label="Training Data", s=1, color="silver")
ax2.set_xlabel('X')
ax2.set_ylabel('Predicted Mean of Y')
ax2.set_title(r'$L_2$ Regression')
#ax2.legend()
ax2.grid(False)

# Adjust layout and display the plots
plt.tight_layout()
#plt.savefig('~/cubic_uniform_est_beta.svg',format='svg')
plt.show()
